# %%
import torch
from ultralytics import YOLO

print(f"torch={torch.__version__}  CUDA={torch.cuda.is_available()}") # THIS IS UNNECESARY IF YOU ARE TRAINING ON GOOGLE COLLAB

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("YOUR-WORKSPACE").project("YOUR-PROJECT")
version = project.version(1)
dataset = version.download("yolov8")

# %%
model = YOLO("yolov8n.pt")  

results = model.train(
    data="YOUR-PATH-DATASET",
    epochs=300,
    imgsz=256,            
    batch=16,
    patience=20,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    project="runs",
    name="train",
)
